# %%
my_integer_var = 12
print('Integer:', my_integer_var) # Integer: 10
# Out:
# Integer: 12

# %%
numeriya = 15
print ('integrer:', numeriya)
# Out:
# integrer: 15

# %%
a_number = 17
print('integer:', a_number)
# Out:
# integer: 17

# %%
a_bird = 4.66
print('float:', a_bird)
# Out:
# float: 4.66

# %%
hey_jude = 'dont make it bad'
print('string:', hey_jude,)
# Out:
# string: dont make it bad

# %%
hey_jude = 'take a sad song'
print ('string:',hey_jude)
# Out:
# string: take a sad song

# %%
abbey_road = 'a london studio'
print ('string:', abbey_road)b
# Out:
# string: a london studio

# %%
does_she = True
print ('boolean:', does_she)
# Out:
# boolean: True

# %%
set_likes = [4,8,9,19]
print ('set:', set_likes)
# Out:
# set: [4, 8, 9, 19]

# %%
band = {'john' : 'lead' , 'george':'guitar'}
print('dictionary:', band)
# Out:
# dictionary: {'john': 'lead', 'george': 'guitar'}

# %%
the_beatles = {'name':'john', 'work':'guitarist', 'age' : 25, 'year' : 1970}
print('dictionary:', the_beatles)
# Out:
# dictionary: {'name': 'john', 'work': 'guitarist', 'age': 25, 'year': 1970}

# %%
vegetables = {'apple', 'banana', 'orange'}
print('set:',vegetables)
# Out:
# set: {'banana', 'orange', 'apple'}

# %%
vegetables = ( 'a1', 'b2' , 'c3' )
print('tuple:' ,vegetables)
# Out:
# tuple: ('a1', 'b2', 'c3')

# %%
my_range = range(7)
print('range:',my_range)
# Out:
# range: range(0, 7)

# %%
songs_list = [ 'abbey', 'road', 'penny']
print('list:',songs_list)
# Out:
# list: ['abbey', 'road', 'penny']

# %%
nowhere_man = None
print('none:',nowhere_man)
# Out:
# none: None

# %%
the_beatles = 'an english band'
total_members = 4
their_names = [ 'john', 'ringo', 'geroge', 'paul']

print(type(the_beatles))
print(type(total_members))
print(type(their_names))
# Out:
# <class 'str'>
# <class 'int'>
# <class 'list'>

# %%
the_beatles = 'an english band'
total_members = 4
their_names = [ 'john', 'ringo', 'geroge', 'paul']
isinstance(45,int)
# Out:
# True

# %%
#lets create a program comprising of all this stuff

the_beatles = 'an english band'
total_members = 4
names = {'paul','john','ringo','george'}
songs = ('jude','penny','madona')
print('str:',the_beatles)
print('the total members were','int', total_members)
print('int:', total_members)
print('and this is the list of their songs', songs)
print('tuple:',songs)
# Out:
# str: an english band
# the total members were int 4
# int: 4
# and this is the list of their songs ('jude', 'penny', 'madona')
# tuple: ('jude', 'penny', 'madona')

# %%
the_beatles = 'its an english band'
print('an' in the_beatles)
print('pink' in the_beatles)
# Out:
# True
# False

# %%
#about the length of an string
the_beatles = 'sgt pepper lonley hearts club band'
print(len(the_beatles))
# Out:
# 34

# %%
#about the index or position of an letter in a string 
Sholay = 'it was a film of 1970s'
print(Sholay[4])
# Out:
# a

# %%
#about the index or position of an letter in a string 
Sholay = 'it was a film of 1970s'
print(Sholay[9])
# Out:
# f

# %%
#about the index or position of an letter in a string 
Sholay = 'it was a film of 1970s'
print(Sholay[-1])
# Out:
# s

# %%
string1 = 'hello'
string2 = 'world'
print(string1, string2)
# Out:
# hello world

# %%
jude1 = 'Hey Jude don\'t make it bad' 
jude2 = 'remeber to let her into your heart'
print(jude1, jude2)
# Out:
# Hey Jude dont make it bad remebe to let her

# %%
jude1 = 'Hey Jude don\'t make it bad' 
jude2 = 'remeber to let her into your heart'
john = jude1 + ' '+ jude2
print(john)
# Out:
# Hey Jude don't make it bad remeber to let her into your heart

# %%
name = 'Manak Soni'
print(name)
# Out:
# Manak Soni

# %%
hindi = 'kishore, lata, rafi'
english = 'the beatles, pink floyd'
years = 7
combined = f'{hindi} {english} are my fav songs since last {years} years'
print(combined )
# Out:
# kishore, lata, rafi the beatles, pink floyd are my fav songs since last 7 years

# %%
hindi = 'kishore kumar'
english = 'the beatles'
years = 15
combined = f'i like music. i like in hindi these artists named {hindi} and in english i like {english}. I have been listening to them since last {years} years'
print(combined)
# Out:
# i like music. i like in hindi these artists named kishore kumar and in english i like the beatles. I have been listening to them since last 15 years

# %%
age = 18

if age >= 18:
 print('You are an adult')
# Out:
# You are an adult

# %%
age = 20
if age >= 25 :
    print('youre adult')
else:
           print('NO')
# Out:
# NO

# %%
sweets = 'rajbhog'
token = 10
if sweets == 'rajbhog' and token > 5 :
 print('mithai le lo')
else : ('NO')
# Out:
# mithai le lo

# %%
snack = 'kacholi'
token_amount = 4
if snack == 'kacholi' and token_amount > 5 : 
  print('mithai tyaar h')
else : 
    print('paisa la')
# Out:
# paisa la

# %%
snack = 'kacholi'
token_amount = 10
if snack == 'kacholi' and token < 11 :
    print('le ja kacholi')
if snack == 'kacholi' and token == 10 :
    print('choti kacholi')
else : 
    print('paisa la')
# Out:
# le ja kacholi
# choti kacholi

# %%
snack = 'kacholi'
token_amount = 14
if snack == 'kacholi' and token < 11 :
    print('le ja kacholi')
if snack == 'kacholi' and token == 10 :
    print('lekin choti kacholi')
else : 
    print('paisa la')
# Out:
# le ja kacholi
# lekin choti kacholi

# %%
snack = 'kacholi'
token_amount = 14
if snack == 'kacholi' and token < 11 :
    print('le ja kacholi')
if snack == 'kacholi' and token == 10 :
    print('lekin choti kacholi')
else : 
    print('paisa la')
# Out:
# le ja kacholi
# lekin choti kacholi

# %%
snack = 'kaccholi'
jaan_pehchan = 'no'
if snack == 'kaccholi' or jaan_pehchan == 'yes' :
    print('aa ja bhaila le ja')
else :
    print ('get lost')
# Out:
# get lost

# %%
is_admin = True 

if not is_admin :
    print ('nikal b**di ke')

else:
    print ('aayiye sir')
# Out:
# aayiye sir

# %%
name = input('what is your name')
print('Hey', name)
# Out:
# what is your name Manak
# Hey Manak

# %%
name = input('What is your confession')
print('hello', name)
# Out:
# What is your confession jhjh
# hello jhjh
